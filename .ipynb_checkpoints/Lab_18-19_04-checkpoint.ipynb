# %%
# %config IPCompleter.greedy=True
import pandas as pd
pd.__version__
# Out:
# u'0.22.0'

# %%
df = pd.read_csv('gapminder.tsv',delimiter='\t')
df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[[1,2],['country','year','pop','lifeExp']]
# Out:
#        country  year       pop  lifeExp
# 1  Afghanistan  1957   9240934   30.332
# 2  Afghanistan  1962  10267083   31.997

# %%
life_mean = df['lifeExp'].mean()
life_mean
# Out:
# 59.474439366197174

# %%
df.groupby('year')['lifeExp','pop'].mean()
# Out:
#         lifeExp           pop
# year
# 1952  49.057620  1.695040e+07
# 1957  51.507401  1.876341e+07
# 1962  53.609249  2.042101e+07
# 1967  55.678290  2.265830e+07
# 1972  57.647386  2.518998e+07
# 1977  59.570157  2.767638e+07
# 1982  61.533197  3.020730e+07
# 1987  63.212613  3.303857e+07
# 1992  64.160338  3.599092e+07
# 1997  65.014676  3.883947e+07
# 2002  65.694923  4.145759e+07
# 2007  67.007423  4.402122e+07

# %%
df.loc[df['lifeExp']>life_mean,:]
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap
# 14               Albania    Europe  1962   64.820   1728137   2312.888958
# 15               Albania    Europe  1967   66.220   1984060   2760.196931
# 16               Albania    Europe  1972   67.690   2263554   3313.422188
# 17               Albania    Europe  1977   68.930   2509048   3533.003910
# 18               Albania    Europe  1982   70.420   2780097   3630.880722
# 19               Albania    Europe  1987   72.000   3075321   3738.932735
# 20               Albania    Europe  1992   71.581   3326498   2497.437901
# 21               Albania    Europe  1997   72.950   3428038   3193.054604
# 22               Albania    Europe  2002   75.651   3508512   4604.211737
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 30               Algeria    Africa  1982   61.368  20033753   5745.160213
# 31               Algeria    Africa  1987   65.799  23254956   5681.358539
# ...

# %%
df.groupby(['continent','country'])['lifeExp','pop'].mean()
# Out:
#                                       lifeExp           pop
# continent country
# Africa    Algeria                   59.030167  1.987541e+07
#           Angola                    37.883500  7.309390e+06
#           Benin                     48.779917  4.017497e+06
#           Botswana                  54.597500  9.711862e+05
#           Burkina Faso              44.694000  7.548677e+06
#           Burundi                   44.817333  4.651608e+06
#           Cameroon                  48.128500  9.816648e+06
#           Central African Republic  43.866917  2.560963e+06
#           Chad                      46.773583  5.329256e+06
#           Comoros                   52.381750  3.616839e+05
#           Congo, Dem. Rep.          44.543750  3.268166e+07
#           Congo, Rep.               52.501917  1.923209e+06
#           Cote d'Ivoire             48.436167  9.153110e+06
#           Djibouti                  46.380750  2.602439e+05
# ...

# %%
df2 = pd.read_csv('scipy-2017-tutorial-pandas-master/data/gapminder.tsv',delimiter='\t')
df2
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
df2.groupby('year')[['lifeExp','pop']].mean()
# Out:
#         lifeExp           pop
# year
# 1952  49.057620  1.695040e+07
# 1957  51.507401  1.876341e+07
# 1962  53.609249  2.042101e+07
# 1967  55.678290  2.265830e+07
# 1972  57.647386  2.518998e+07
# 1977  59.570157  2.767638e+07
# 1982  61.533197  3.020730e+07
# 1987  63.212613  3.303857e+07
# 1992  64.160338  3.599092e+07
# 1997  65.014676  3.883947e+07
# 2002  65.694923  4.145759e+07
# 2007  67.007423  4.402122e+07

# %%
df2.loc[[9,99,999],:]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 9    Afghanistan      Asia  1997   41.763  22227415   635.341351
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
mean_gdp = df2['gdpPercap'].mean()
mean_gdp
# Out:
# 7215.327081212149

# %%
df2.loc[df2['gdpPercap']>mean_gdp,:]
# Out:
#              country continent  year  lifeExp        pop     gdpPercap
# 51         Argentina  Americas  1967   65.634   22934225   8052.953021
# 52         Argentina  Americas  1972   67.065   24779799   9443.038526
# 53         Argentina  Americas  1977   68.481   26983828  10079.026740
# 54         Argentina  Americas  1982   69.942   29341374   8997.897412
# 55         Argentina  Americas  1987   70.774   31620918   9139.671389
# 56         Argentina  Americas  1992   71.868   33958947   9308.418710
# 57         Argentina  Americas  1997   73.275   36203463  10967.281950
# 58         Argentina  Americas  2002   74.340   38331121   8797.640716
# 59         Argentina  Americas  2007   75.320   40301927  12779.379640
# 60         Australia   Oceania  1952   69.120    8691212  10039.595640
# 61         Australia   Oceania  1957   70.330    9712569  10949.649590
# 62         Australia   Oceania  1962   70.930   10794968  12217.226860
# ...

# %%
df2.iloc[[0,9,99,999],:]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 9    Afghanistan      Asia  1997   41.763  22227415   635.341351
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df2.iloc[[0,9,99,999],:]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 0    Afghanistan      Asia  1952   28.801   8425333   779.445314
# 9    Afghanistan      Asia  1997   41.763  22227415   635.341351
# 99    Bangladesh      Asia  1967   43.453  62821884   721.186086
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df2.groupby('year')[['lifeExp','pop','gdpPercap']].mean()
# Out:
#         lifeExp           pop     gdpPercap
# year
# 1952  49.057620  1.695040e+07   3725.276046
# 1957  51.507401  1.876341e+07   4299.408345
# 1962  53.609249  2.042101e+07   4725.812342
# 1967  55.678290  2.265830e+07   5483.653047
# 1972  57.647386  2.518998e+07   6770.082815
# 1977  59.570157  2.767638e+07   7313.166421
# 1982  61.533197  3.020730e+07   7518.901673
# 1987  63.212613  3.303857e+07   7900.920218
# 1992  64.160338  3.599092e+07   8158.608521
# 1997  65.014676  3.883947e+07   9090.175363
# 2002  65.694923  4.145759e+07   9917.848365
# 2007  67.007423  4.402122e+07  11680.071820

# %%
df2.groupby(['year','continent'])\
[['lifeExp','pop','gdpPercap']].\
mean()
# Out:
#                   lifeExp           pop     gdpPercap
# year continent
# 1952 Africa     39.135500  4.570010e+06   1252.572466
#      Americas   53.279840  1.380610e+07   4079.062552
#      Asia       46.314394  4.228356e+07   5195.484004
#      Europe     64.408500  1.393736e+07   5661.057435
#      Oceania    69.255000  5.343003e+06  10298.085650
# 1957 Africa     41.266346  5.093033e+06   1385.236062
#      Americas   55.960280  1.547816e+07   4616.043733
#      Asia       49.318544  4.735699e+07   5787.732940
#      Europe     66.703067  1.459635e+07   6963.012816
#      Oceania    70.295000  5.970988e+06  11598.522455
# 1962 Africa     43.319442  5.702247e+06   1598.078825
#      Americas   58.398760  1.733081e+07   4901.541870
#      Asia       51.563223  5.140476e+07   5729.369625
#      Europe     68.539233  1.534517e+07   8365.486814
#      Oceania    71.085000  6.641759e+06  12696.452430
# 1967 Africa     45.334538  6.447875e+06   2050.363801
# ...

# %%
df2.groupby(['continent'])['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df2.groupby(['continent'])['lifeExp'].mean()
# Out:
# continent
# Africa      48.865330
# Americas    64.658737
# Asia        60.064903
# Europe      71.903686
# Oceania     74.326208
# Name: lifeExp, dtype: float64

# %%
df2.loc[[1,2,3],:]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
df2.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df2.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df2['country'].nunique()
# Out:
# 142

# %%
df2.iloc[[1,2,3],[0,1,2,3,4,5]]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138

# %%
gdp_mean = df2['gdpPercap'].mean()
gdp_mean
# Out:
# 7215.327081212149

# %%
df2.ix[df2['gdpPercap']>gdp_mean]
# Out:
#              country continent  year  lifeExp        pop     gdpPercap
# 51         Argentina  Americas  1967   65.634   22934225   8052.953021
# 52         Argentina  Americas  1972   67.065   24779799   9443.038526
# 53         Argentina  Americas  1977   68.481   26983828  10079.026740
# 54         Argentina  Americas  1982   69.942   29341374   8997.897412
# 55         Argentina  Americas  1987   70.774   31620918   9139.671389
# 56         Argentina  Americas  1992   71.868   33958947   9308.418710
# 57         Argentina  Americas  1997   73.275   36203463  10967.281950
# 58         Argentina  Americas  2002   74.340   38331121   8797.640716
# 59         Argentina  Americas  2007   75.320   40301927  12779.379640
# 60         Australia   Oceania  1952   69.120    8691212  10039.595640
# 61         Australia   Oceania  1957   70.330    9712569  10949.649590
# 62         Australia   Oceania  1962   70.930   10794968  12217.226860
# ...

# %%
df2.iloc[[0,-1,-2,-3],[0,1,2,3]]
# Out:
#           country continent  year  lifeExp
# 0     Afghanistan      Asia  1952   28.801
# 1703     Zimbabwe    Africa  2007   43.487
# 1702     Zimbabwe    Africa  2002   39.989
# 1701     Zimbabwe    Africa  1997   46.809

# %%
df2.iloc[[0,-1,-2,-3],:]
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960

# %%
df2.loc[[1,9,999]]
# Out:
#          country continent  year  lifeExp       pop    gdpPercap
# 1    Afghanistan      Asia  1957   30.332   9240934   820.853030
# 9    Afghanistan      Asia  1997   41.763  22227415   635.341351
# 999     Mongolia      Asia  1967   51.253   1149500  1226.041130

# %%
df2.loc[[1,2,3,4,5],:]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360

# %%
gyle=df2.groupby('year')['lifeExp'].mean()
gyle
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
gyle.plot()

# %%
gyle2=df2.groupby('continent')['lifeExp'].mean()
gyle2
# Out:
# continent
# Africa      48.865330
# Americas    64.658737
# Asia        60.064903
# Europe      71.903686
# Oceania     74.326208
# Name: lifeExp, dtype: float64

# %%
# gyle2.plot()
gyle.plot()

# %%
gyle.reset_index()
# Out:
#     year    lifeExp
# 0   1952  49.057620
# 1   1957  51.507401
# 2   1962  53.609249
# 3   1967  55.678290
# 4   1972  57.647386
# 5   1977  59.570157
# 6   1982  61.533197
# 7   1987  63.212613
# 8   1992  64.160338
# 9   1997  65.014676
# 10  2002  65.694923
# 11  2007  67.007423

# %%
df=gyle.reset_index()

# %%
df.to_csv('lifeExp_by_Year.csv',index=False)
